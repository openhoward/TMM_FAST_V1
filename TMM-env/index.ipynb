# %%
import torch
print("Torch version:", torch.__version__)

from tmm_fast.tmm_autograd import coh_tmm_autograd
# Example usage if installed correctly:
# result = coh_tmm_autograd('s', n_list, d_list, th_0, lam_vac, pol=None)
